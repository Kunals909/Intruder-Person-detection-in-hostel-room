# %% [markdown]
# ## Intruder Detection using YOLOv5 architecture model

# %% [markdown]
#  This jupter notebook requires colab to run.
#     <br> We have mount the  "CODE" folder in drive and run the below code

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/Kunal_Python/Code/yolov5
# Out:
# /content/drive/MyDrive/Kunal_Python

# %% [markdown]
# ## Installing all required Libaries

# %%
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.10.0+cu111 (Tesla P100-PCIE-16GB)

# %%
##

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()
# Out:
#      |████████████████████████████████| 1.7 MB 13.3 MB/s
#      |████████████████████████████████| 140 kB 71.2 MB/s
#      |████████████████████████████████| 97 kB 8.8 MB/s
#      |████████████████████████████████| 180 kB 71.1 MB/s
#      |████████████████████████████████| 63 kB 2.1 MB/s
# ...
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
python train.py --data custom.yaml --weights '' --cfg yolov5s.yaml

# %% [markdown]
#  ##                                 Training of dataset using YOLOv5s model

# %%
# !python train.py --img 640 --batch 16 --epochs 300 --data customdata.yaml --weights yolov5s.pt --cache
# Out:
# wandb: Currently logged in as: shivam9810 (use `wandb login --relogin` to force relogin)
# train: weights=yolov5s.pt, cfg=, data=customdata.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 2021-12-3 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
#  ##                                 Training of dataset using YOLOv5l model

# %%
# !python train.py --img 640 --batch 16 --epochs 300 --data customdata.yaml --weights yolov5l.pt --cache
# Out:
# wandb: Currently logged in as: shivam9810 (use `wandb login --relogin` to force relogin)
# train: weights=yolov5l.pt, cfg=, data=customdata.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 2021-12-3 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %% [markdown]
# ### Training of Dataset with YOLOv5x model

# %%
# !python train.py --img 640 --batch 16 --epochs 300 --data customdata.yaml --weights yolov5x.pt --cache
# Out:
# wandb: Currently logged in as: shivam9810 (use `wandb login --relogin` to force relogin)
# train: weights=yolov5x.pt, cfg=, data=customdata.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 2 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 2021-12-3 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %%
# %cd yolov5
# Out:
# /content/drive/My Drive/Kunal_Python/Code/yolov5

# %%
# !python train.py --resume
# Out:
# wandb: Currently logged in as: shivam9810 (use `wandb login --relogin` to force relogin)
# train: weights=yolov5s.pt, cfg=, data=data/coco128.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=True, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 2 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# Resuming training from ./runs/train/exp15/weights/last.pt
# YOLOv5 🚀 2021-12-3 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %% [markdown]
# ## Testing the prediction of model on the new test images

# %%
# !python detect.py --weights "/content/drive/MyDrive/Kunal_Python/Code/yolov5/runs/train/exp12/weights/best.pt" --img 640 --conf 0.25 --source "/content/drive/MyDrive/Kunal_Python/Code/DATA/images/test"
# Out:
# detect: weights=['/content/drive/MyDrive/Kunal_Python/Code/yolov5/runs/train/exp12/weights/best.pt'], source=/content/drive/MyDrive/Kunal_Python/Code/DATA/images/test, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-122-gd885799 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/91 /content/drive/MyDrive/Kunal_Python/Code/DATA/images/test/IMG_2234_0.jpg: 384x640 1 R1, 1 Unknown, Done. (0.013s)
# image 2/91 /content/drive/MyDrive/Kunal_Python/Code/DATA/images/test/IMG_2234_1008.jpg: 384x640 1 R2, 1 Unknown, Done. (0.008s)
# ...

# %% [markdown]
# ## Testing the prediction of model on the new test vedio

# %%
# !python detect.py --weights "/content/drive/MyDrive/Kunal_Python/Code/yolov5/runs/train/exp12/weights/best.pt" --img 640 --conf 0.25 --source "/content/drive/MyDrive/Kunal_Python/Vedios/IMG_2234.MOV"
# Out:
# detect: weights=['/content/drive/MyDrive/Kunal_Python/Code/yolov5/runs/train/exp12/weights/best.pt'], source=/content/drive/MyDrive/Kunal_Python/Vedios/IMG_2234.MOV, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-12-3 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/2336) /content/drive/MyDrive/Kunal_Python/Vedios/IMG_2234.MOV: 384x640 1 R1, 1 Unknown, Done. (0.015s)
# video 1/1 (2/2336) /content/drive/MyDrive/Kunal_Python/Vedios/IMG_2234.MOV: 384x640 1 R1, 1 Unknown, Done. (0.038s)
# ...

# %% [markdown]
# ## Testing of pretrained model with test vedio

# %%
# !python detect.py --weights "/content/drive/MyDrive/Kunal_Python/Code/yolov5/runs/train/exp12/weights/best.pt" --img 640 --conf 0.25 --source "/content/drive/MyDrive/Kunal_Python/Code/VID20211204225414.mp4"
# Out:
# detect: weights=['/content/drive/MyDrive/Kunal_Python/Code/yolov5/runs/train/exp12/weights/best.pt'], source=/content/drive/MyDrive/Kunal_Python/Code/VID20211204225414.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-122-gd885799 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/383) /content/drive/MyDrive/Kunal_Python/Code/VID20211204225414.mp4: 384x640 Done. (0.012s)
# video 1/1 (2/383) /content/drive/MyDrive/Kunal_Python/Code/VID20211204225414.mp4: 384x640 Done. (0.013s)
# ...

# %% [markdown]
# ## Performance on test set for YOLOv5s

# %%
# !python val.py --weights "/content/drive/MyDrive/Kunal_Python/Code/yolov5/runs/train/exp12/weights/best.pt" --data customdata.yaml --img 640 --iou 0.65 --half --task test
# Out:
# val: data=/content/drive/My Drive/Kunal_Python/Code/yolov5/data/customdata.yaml, weights=['/content/drive/MyDrive/Kunal_Python/Code/yolov5/runs/train/exp12/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 2021-12-3 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning '../DATA/labels/test' images and labels...91 found, 0 missing, 0 empty, 0 corrupted: 100% 91/91 [00:58<00:00,  1.56it/s]
# test: New cache created: ../DATA/labels/test.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:05<00:00,  1.89s/it]
# ...

# %% [markdown]
# ## Performance on test set for YOLOv5m

# %%
# !python val.py --weights "/content/drive/MyDrive/Kunal_Python/Code/yolov5/runs/train/exp13/weights/best.pt" --data customdata.yaml --img 640 --iou 0.65 --half --task test
# Out:
# val: data=/content/drive/My Drive/Kunal_Python/Code/yolov5/data/customdata.yaml, weights=['/content/drive/MyDrive/Kunal_Python/Code/yolov5/runs/train/exp13/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 2021-12-3 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20861016 parameters, 0 gradients, 48.0 GFLOPs
# test: Scanning '../DATA/labels/test.cache' images and labels... 91 found, 0 missing, 0 empty, 0 corrupted: 100% 91/91 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:04<00:00,  1.63s/it]
#                  all         91        150      0.923      0.517       0.66      0.283
# ...

# %% [markdown]
# ## Performance on test set for YOLOv5l

# %%
# !python val.py --weights "/content/drive/MyDrive/Kunal_Python/Code/yolov5/runs/train/exp14/weights/best.pt" --data customdata.yaml --img 640 --iou 0.65 --half --task test
# Out:
# val: data=/content/drive/My Drive/Kunal_Python/Code/yolov5/data/customdata.yaml, weights=['/content/drive/MyDrive/Kunal_Python/Code/yolov5/runs/train/exp14/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 2021-12-3 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46119048 parameters, 0 gradients, 107.8 GFLOPs
# test: Scanning '../DATA/labels/test.cache' images and labels... 91 found, 0 missing, 0 empty, 0 corrupted: 100% 91/91 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:05<00:00,  1.69s/it]
#                  all         91        150       0.65      0.706      0.678      0.287
# ...

# %% [markdown]
# ## Performance on test set for YOLOv5x

# %%
# !python val.py --weights "/content/drive/MyDrive/Kunal_Python/Code/yolov5/runs/train/exp17/weights/best.pt" --data customdata.yaml --img 640 --iou 0.65 --half --task test
# Out:
# val: data=/content/drive/My Drive/Kunal_Python/Code/yolov5/data/customdata.yaml, weights=['/content/drive/MyDrive/Kunal_Python/Code/yolov5/runs/train/exp17/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 2021-12-3 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86186872 parameters, 0 gradients, 204.0 GFLOPs
# test: Scanning '../DATA/labels/test.cache' images and labels... 91 found, 0 missing, 0 empty, 0 corrupted: 100% 91/91 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:05<00:00,  1.83s/it]
#                  all         91        150       0.69      0.655      0.673      0.295
# ...

# %% [markdown]
# ## GPU Specification

# %%
# !nvidia-smi
# Out:
# Sun Dec  5 23:48:25 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    27W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## End Of Code
